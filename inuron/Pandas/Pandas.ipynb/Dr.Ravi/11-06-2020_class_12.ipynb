# %%
#Pandas

# %%
import pandas as pd
s1 = pd.Series([1,2,3,4,5])

# %%
df1 = pd.DataFrame(s1)

# %%
s2 = pd.Series([4,5,6,7,8,9])

# %%
df2 = pd.DataFrame(s2)

# %%
df1
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
df2
# Out:
#    0
# 0  4
# 1  5
# 2  6
# 3  7
# 4  8
# 5  9

# %%
pd.concat([df1,df2])
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5
# 0  4
# 1  5
# 2  6
# 3  7
# 4  8
# 5  9

# %%
pd.concat([df1,df2], axis=0)
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5
# 0  4
# 1  5
# 2  6
# 3  7
# 4  8
# 5  9

# %%
pd.concat([df1,df2], axis=0)
# Out:
#    0     1
# 0  1  34.0
# 1  2  35.0
# 2  3  36.0
# 3  4  37.0
# 4  5  38.0
# 0  4   NaN
# 1  5   NaN
# 2  6   NaN
# 3  7   NaN
# 4  8   NaN
# 5  9   NaN

# %%
df1[1] = pd.Series([34,35,36,37,38])

# %%
df1
# Out:
#    0   1
# 0  1  34
# 1  2  35
# 2  3  36
# 3  4  37
# 4  5  38

# %%
row = pd.Series([0,1])

# %%
import os
os.getcwd()
# Out:
# '/home/labsuser'

# %%
os.chdir('/home/labsuser/Amrit/')

# %%
data = pd.read_csv('credit_data.csv')

# %%
data.iloc[:, 0:4]
# Out:
#       clientid        income        age         loan
# 0            1  66155.925095  59.017015  8106.532131
# 1            2  34415.153966  48.117153  6564.745018
# 2            3  57317.170063  63.108049  8020.953296
# 3            4  42709.534201  45.751972  6103.642260
# 4            5  66952.688845  18.584336  8770.099235
# ...        ...           ...        ...          ...
# 1995      1996  59221.044874  48.518179  1926.729397
# 1996      1997  69516.127573  23.162104  3503.176156
# 1997      1998  44311.449262  28.017167  5522.786693
# 1998      1999  43756.056605  63.971796  1622.722598
# 1999      2000  69436.579552  56.152617  7378.833599
#
# [2000 rows x 4 columns]

# %%
data.drop(['clientid'], axis=1, inplace=True)

# %%
data
# Out:
#             income        age         loan       LTI  default
# 0     66155.925095  59.017015  8106.532131  0.122537        0
# 1     34415.153966  48.117153  6564.745018  0.190752        0
# 2     57317.170063  63.108049  8020.953296  0.139940        0
# 3     42709.534201  45.751972  6103.642260  0.142911        0
# 4     66952.688845  18.584336  8770.099235  0.130989        1
# ...            ...        ...          ...       ...      ...
# 1995  59221.044874  48.518179  1926.729397  0.032535        0
# 1996  69516.127573  23.162104  3503.176156  0.050394        0
# 1997  44311.449262  28.017167  5522.786693  0.124636        1
# 1998  43756.056605  63.971796  1622.722598  0.037086        0
# 1999  69436.579552  56.152617  7378.833599  0.106267        0
#
# [2000 rows x 5 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   income   2000 non-null   float64
#  1   age      2000 non-null   float64
#  2   loan     2000 non-null   float64
#  3   LTI      2000 non-null   float64
#  4   default  2000 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 78.2 KB

# %%
data.describe()
# Out:
#              income          age          loan          LTI      default
# count   2000.000000  2000.000000   2000.000000  2000.000000  2000.000000
# mean   45331.600018    40.927143   4444.369695     0.098403     0.141500
# std    14326.327119    13.262450   3045.410024     0.057620     0.348624
# min    20014.489470    18.055189      1.377630     0.000049     0.000000
# 25%    32796.459717    29.062492   1939.708847     0.047903     0.000000
# 50%    45789.117313    41.382673   3974.719419     0.099437     0.000000
# 75%    57791.281668    52.596993   6432.410625     0.147585     0.000000
# max    69995.685578    63.971796  13766.051239     0.199938     1.000000

# %%
import numpy as np
data['dummy'] = np.zeros(2000)

# %%
data.columns
# Out:
# Index(['income', 'age', 'loan', 'LTI', 'default', 5, 'dummy'], dtype='object')

# %%
df1
# Out:
#    0   1
# 0  1  34
# 1  2  35
# 2  3  36
# 3  4  37
# 4  5  38

# %%
df2
# Out:
#    0
# 0  4
# 1  5
# 2  6
# 3  7
# 4  8
# 5  9

# %%
dict1 = {"Teams":['India', 'SL', 'PK','AUS','NZ'], "WINS":[5,6,7,8,9],"Loss":[4,3,2,1,7]}

# %%
df1 = pd.DataFrame(dict1)

# %%
dict3 = {"Teams":['ENG', 'ZBW', 'HOL','BAN','SA'], "TROPHIES":[15,16,17,18,19],"BATSMAN":[1,2,3,4,7]}

# %%
df3 = pd.DataFrame(dict3)

# %%
dict2 = {"Teams":['India', 'SL', 'PK','AUS','NZ'], "TROPHIES":[15,16,17,18,19],"BATSMAN":[1,2,3,4,7]}

# %%
df3
# Out:
#   Teams  TROPHIES  BATSMAN
# 0   ENG        15        1
# 1   ZBW        16        2
# 2   HOL        17        3
# 3   BAN        18        4
# 4    SA        19        7

# %%
df2 = pd.DataFrame(dict2)

# %%
pd.merge(df1,df2)
# Out:
#    Teams  WINS  Loss  TROPHIES  BATSMAN
# 0  India     5     4        15        1
# 1     SL     6     3        16        2
# 2     PK     7     2        17        3
# 3    AUS     8     1        18        4
# 4     NZ     9     7        19        7

# %%
df1.merge(df3, on="Teams", how='left')
# Out:
#    Teams  WINS  Loss  TROPHIES  BATSMAN
# 0  India     5     4       NaN      NaN
# 1     SL     6     3       NaN      NaN
# 2     PK     7     2       NaN      NaN
# 3    AUS     8     1       NaN      NaN
# 4     NZ     9     7       NaN      NaN

# %%
df1.merge(df3, on="Teams", how='right')
# Out:
#   Teams  WINS  Loss  TROPHIES  BATSMAN
# 0   ENG   NaN   NaN        15        1
# 1   ZBW   NaN   NaN        16        2
# 2   HOL   NaN   NaN        17        3
# 3   BAN   NaN   NaN        18        4
# 4    SA   NaN   NaN        19        7

# %%
df1.merge(df3, on="Teams", how='inner')
# Out:
# Empty DataFrame
# Columns: [Teams, WINS, Loss, TROPHIES, BATSMAN]
# Index: []

# %%
df1.merge(df2, on="Teams", how='inner')
# Out:
#    Teams  WINS  Loss  TROPHIES  BATSMAN
# 0  India     5     4        15        1
# 1     SL     6     3        16        2
# 2     PK     7     2        17        3
# 3    AUS     8     1        18        4
# 4     NZ     9     7        19        7

# %%
df1.merge(df2, on="Teams", how='outer')
# Out:
#    Teams  WINS  Loss  TROPHIES  BATSMAN
# 0  India     5     4        15        1
# 1     SL     6     3        16        2
# 2     PK     7     2        17        3
# 3    AUS     8     1        18        4
# 4     NZ     9     7        19        7

# %%
df1.merge(df3, on="Teams", how='outer')
# Out:
#    Teams  WINS  Loss  TROPHIES  BATSMAN
# 0  India   5.0   4.0       NaN      NaN
# 1     SL   6.0   3.0       NaN      NaN
# 2     PK   7.0   2.0       NaN      NaN
# 3    AUS   8.0   1.0       NaN      NaN
# 4     NZ   9.0   7.0       NaN      NaN
# 5    ENG   NaN   NaN      15.0      1.0
# 6    ZBW   NaN   NaN      16.0      2.0
# 7    HOL   NaN   NaN      17.0      3.0
# 8    BAN   NaN   NaN      18.0      4.0
# 9     SA   NaN   NaN      19.0      7.0

# %%
#Aggregations
df1
# Out:
#    Teams  WINS  Loss
# 0  India     5     4
# 1     SL     6     3
# 2     PK     7     2
# 3    AUS     8     1
# 4     NZ     9     7

# %%
df1.groupby('Teams').groups
# Out:
# {'AUS': Int64Index([3], dtype='int64'),
#  'India': Int64Index([0], dtype='int64'),
#  'NZ': Int64Index([4], dtype='int64'),
#  'PK': Int64Index([2], dtype='int64'),
#  'SL': Int64Index([1], dtype='int64')}

# %%
df1.groupby(['Teams','Loss']).groups
# Out:
# {('AUS', 1): Int64Index([3], dtype='int64'),
#  ('India', 4): Int64Index([0], dtype='int64'),
#  ('NZ', 7): Int64Index([4], dtype='int64'),
#  ('PK', 2): Int64Index([2], dtype='int64'),
#  ('SL', 3): Int64Index([1], dtype='int64')}

# %%
grouped = df1.groupby("Teams")

# %%
for name in grouped:
    print(name)
# Out:
# ('AUS',   Teams  WINS  Loss
# 3   AUS     8     1)
# ('India',    Teams  WINS  Loss
# 0  India     5     4)
# ('NZ',   Teams  WINS  Loss
# 4    NZ     9     7)
# ('PK',   Teams  WINS  Loss
# 2    PK     7     2)
# ('SL',   Teams  WINS  Loss
# 1    SL     6     3)

# %%
for name,group in grouped:
    print(name)
# Out:
# AUS
# India
# NZ
# PK
# SL

# %%
grouped.get_group('India')
# Out:
#    Teams  WINS  Loss
# 0  India     5     4

# %%
grouped.get_group("NZ")
# Out:
#   Teams  WINS  Loss
# 4    NZ     9     7

# %%
data
# Out:
#             income        age         loan       LTI  default    5  dummy
# 0     66155.925095  59.017015  8106.532131  0.122537        0  0.0    0.0
# 1     34415.153966  48.117153  6564.745018  0.190752        0  0.0    0.0
# 2     57317.170063  63.108049  8020.953296  0.139940        0  0.0    0.0
# 3     42709.534201  45.751972  6103.642260  0.142911        0  0.0    0.0
# 4     66952.688845  18.584336  8770.099235  0.130989        1  0.0    0.0
# ...            ...        ...          ...       ...      ...  ...    ...
# 1995  59221.044874  48.518179  1926.729397  0.032535        0  0.0    0.0
# 1996  69516.127573  23.162104  3503.176156  0.050394        0  0.0    0.0
# 1997  44311.449262  28.017167  5522.786693  0.124636        1  0.0    0.0
# 1998  43756.056605  63.971796  1622.722598  0.037086        0  0.0    0.0
# 1999  69436.579552  56.152617  7378.833599  0.106267        0  0.0    0.0
#
# [2000 rows x 7 columns]

# %%
data.shape
# Out:
# (2000, 7)

# %%
select = data.loc[:, ["age", "loan"]]

# %%
select
# Out:
#             age         loan
# 0     59.017015  8106.532131
# 1     48.117153  6564.745018
# 2     63.108049  8020.953296
# 3     45.751972  6103.642260
# 4     18.584336  8770.099235
# ...         ...          ...
# 1995  48.518179  1926.729397
# 1996  23.162104  3503.176156
# 1997  28.017167  5522.786693
# 1998  63.971796  1622.722598
# 1999  56.152617  7378.833599
#
# [2000 rows x 2 columns]

# %%
for i in select.itertuples():
    if i[1] > 50:
        print(i)
# Out:
# Pandas(Index=0, age=59.017015066929204, loan=8106.53213128514)
# Pandas(Index=2, age=63.10804949188599, loan=8020.953296386469)
# Pandas(Index=5, age=57.4716071025468, loan=15.498598437827198)
# Pandas(Index=8, age=55.496852539479704, loan=4755.8252798016)
# Pandas(Index=11, age=60.4719358547591, loan=9254.24453803174)
# Pandas(Index=13, age=61.576775823254096, loan=4759.7875810455)
# Pandas(Index=17, age=60.84831793932239, loan=3277.7375531263)
# Pandas(Index=18, age=61.6905707078986, loan=3157.4422899706606)
# Pandas(Index=21, age=52.423279919661596, loan=4244.057136123401)
# Pandas(Index=23, age=51.9706241027452, loan=4959.92122589578)
# Pandas(Index=27, age=55.83992184512321, loan=6376.82294883561)
# Pandas(Index=29, age=54.510947563685505, loan=10871.1867897838)
# Pandas(Index=31, age=52.6710122944787, loan=2862.0101387461)
# Pandas(Index=36, age=58.185017302632296, loan=2109.2007717368697)
# Pandas(Index=37, age=50.2250059167854, loan=4326.70507344396)
# ...

# %%
df1
# Out:
#    Teams  WINS  Loss
# 0  India     5     4
# 1     SL     6     3
# 2     PK     7     2
# 3    AUS     8     1
# 4     NZ     9     7

# %%
for key, value in df1.iteritems():
    print(key, value)
# Out:
# Teams 0    India
# 1       SL
# 2       PK
# 3      AUS
# 4       NZ
# Name: Teams, dtype: object
# WINS 0    5
# 1    6
# 2    7
# 3    8
# 4    9
# Name: WINS, dtype: int64
# Loss 0    4
# 1    3
# 2    2
# 3    1
# 4    7
# Name: Loss, dtype: int64

# %%
for key, value in df1.iterrows():
    print(key, value)
# Out:
# 0 Teams    India
# WINS         5
# Loss         4
# Name: 0, dtype: object
# 1 Teams    SL
# WINS      6
# Loss      3
# Name: 1, dtype: object
# 2 Teams    PK
# WINS      7
# Loss      2
# Name: 2, dtype: object
# 3 Teams    AUS
# WINS       8
# Loss       1
# Name: 3, dtype: object
# 4 Teams    NZ
# WINS      9
# Loss      7
# Name: 4, dtype: object

# %%
for row in df1.itertuples():
    print(row)
# Out:
# Pandas(Index=0, Teams='India', WINS=5, Loss=4)
# Pandas(Index=1, Teams='SL', WINS=6, Loss=3)
# Pandas(Index=2, Teams='PK', WINS=7, Loss=2)
# Pandas(Index=3, Teams='AUS', WINS=8, Loss=1)
# Pandas(Index=4, Teams='NZ', WINS=9, Loss=7)

# %%
df2 = pd.read_csv('credit_data.csv', skiprows=2)

# %%
df2
# Out:
#          2  34415.1539658196  48.1171531048603  6564.74501767738  \
# 0        3      57317.170063         63.108049       8020.953296
# 1        4      42709.534201         45.751972       6103.642260
# 2        5      66952.688845         18.584336       8770.099235
# 3        6      24904.064140         57.471607         15.498598
# 4        7      48430.359613         26.809132       5722.581981
# ...    ...               ...               ...               ...
# 1993  1996      59221.044874         48.518179       1926.729397
# 1994  1997      69516.127573         23.162104       3503.176156
# 1995  1998      44311.449262         28.017167       5522.786693
# 1996  1999      43756.056605         63.971796       1622.722598
# 1997  2000      69436.579552         56.152617       7378.833599
#
#       0.190751580661163  0
# 0              0.139940  0
# 1              0.142911  0
# 2              0.130989  1
# 3              0.000622  0
# 4              0.118161  0
# ...

# %%
df1
# Out:
#    Teams  WINS  Loss
# 0  India     5     4
# 1     SL     6     3
# 2     PK     7     2
# 3    AUS     8     1
# 4     NZ     9     7

# %%
df3
# Out:
#     0
# a  11
# b  12
# c  14
# d  16
# e  17

# %%
df1+df3
# Out:
#    BATSMAN  Loss  TROPHIES     Teams  WINS
# 0      NaN   NaN       NaN  IndiaENG   NaN
# 1      NaN   NaN       NaN     SLZBW   NaN
# 2      NaN   NaN       NaN     PKHOL   NaN
# 3      NaN   NaN       NaN    AUSBAN   NaN
# 4      NaN   NaN       NaN      NZSA   NaN

# %%
df1 = pd.Series([1,2,4,6,7], index=['a','b','c','d','e'])

# %%
df1
# Out:
# a    1
# b    2
# c    4
# d    6
# e    7
# dtype: int64

# %%
df2 = pd.Series([11,12,14,16,17], index=['a','b','x','d','e'])

# %%
df1+df2
# Out:
# a    22.0
# b    24.0
# c     NaN
# d    32.0
# e    34.0
# x     NaN
# dtype: float64

# %%
df3=pd.DataFrame(df1)

# %%
df4=pd.DataFrame(df2)

# %%
df5=df3+df4

# %%
df5.isna()
# Out:
#        0
# a  False
# b  False
# c   True
# d  False
# e  False
# x   True

# %%
df5.isna().sum()
# Out:
# 0    2
# dtype: int64

# %%
df5.fillna(0)
# Out:
#       0
# a  22.0
# b  24.0
# c   0.0
# d  32.0
# e  34.0
# x   0.0

# %%
df5.fillna(df5.mean())
# Out:
#       0
# a  22.0
# b  24.0
# c  28.0
# d  32.0
# e  34.0
# x  28.0

# %%
df5.dropna()
# Out:
#       0
# a  22.0
# b  24.0
# d  32.0
# e  34.0

# %%
df
# Out:
# a    11
# b    12
# x    14
# d    16
# e    17
# dtype: int64

# %%
df1
# Out:
#    Teams  WINS  Loss
# 0  India     5     4
# 1     SL     6     3
# 2     PK     7     2
# 3    AUS     8     1
# 4     NZ     9     7

# %%
def rating(WINS):
    if WINS==9:
        return "A"
    if WINS==8:
        return "B"
    if WINS==7:
        return "C"
    if WINS==6:
        return "D"
    if WINS==5:
        return "E"
    else:
        return "Poor"

# %%
rating(6)
# Out:
# 'D'

# %%
df1[['WINS', 'Loss']].applymap(rating)
# Out:
#   WINS  Loss
# 0    E  Poor
# 1    D  Poor
# 2    C  Poor
# 3    B  Poor
# 4    A     C

# %%
df1
# Out:
#    Teams  WINS  Loss
# 0  India     5     4
# 1     SL     6     3
# 2     PK     7     2
# 3    AUS     8     1
# 4     NZ     9     7

# %%
df1.sort_values('Loss', ascending=False)
# Out:
#    Teams  WINS  Loss
# 4     NZ     9     7
# 0  India     5     4
# 1     SL     6     3
# 2     PK     7     2
# 3    AUS     8     1

# %%
df1.drop(['Teams'], axis=1, inplace=True)

# %%
df1
# Out:
#    WINS  Loss
# 0     5     4
# 1     6     3
# 2     7     2
# 3     8     1
# 4     9     7

# %%
def z(x):
    return x-x.mean()/x.std()

# %%
z(df1)
# Out:
#        WINS      Loss
# 0  0.572811  2.523134
# 1  1.572811  1.523134
# 2  2.572811  0.523134
# 3  3.572811 -0.476866
# 4  4.572811  5.523134

# %% [markdown]
# # SQl

# %%
#Pandas
import sqlite3

# %%
#SQLTABLE
create_table = """
CREATE TABLE student_score
(Id INTEGER, Name VARCHAR(20), MATH REAL, Science REAL);"""

# %%
#execute sql statements                                   # (':memory:')
executeSQL = sqlite3.connect(':memory:')
executeSQL.execute(create_table)
executeSQL.commit()

# %%
#sql query
SQL_query = executeSQL.execute('select * from student_score')

# %%
resultset = SQL_query.fetchall()

# %%
resultset
# Out:
# []

# %%
insertSQL = [(12, 'A', 78,96), 
             (13, 'B', 8,9), 
             (14, 'C', 7,96), 
             (15, 'D', 78,9)]

# %%
insert_statement = "Insert into student_score values(?,?,?,?)"

# %%
executeSQL.executemany(insert_statement, insertSQL)
executeSQL.commit()

# %%
SQL_query = executeSQL.execute('select * from student_score')

# %%
resultset = SQL_query.fetchall()

# %%
resultset
# Out:
# [(12, 'A', 78.0, 96.0),
#  (13, 'B', 8.0, 9.0),
#  (14, 'C', 7.0, 96.0),
#  (15, 'D', 78.0, 9.0),
#  (12, 'A', 78.0, 96.0),
#  (13, 'B', 8.0, 9.0),
#  (14, 'C', 7.0, 96.0),
#  (15, 'D', 78.0, 9.0)]
