# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:\\Users\\himan\\Desktop\\Simpli_class\\Live Class_02\\data\\movie_metadata.csv')
df.head(2)
# Out:
#    color   director_name  num_critic_for_reviews  duration  \
# 0  Color   James Cameron                   723.0     178.0
# 1  Color  Gore Verbinski                   302.0     169.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy  ...
#
#   num_user_for_reviews language  country  content_rating       budget  \
# 0               3054.0  English      USA           PG-13  237000000.0
# 1               1238.0  English      USA           PG-13  300000000.0
#
#    title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0      2009.0                  936.0        7.9          1.78
# ...

# %%
pd.set_option('display.max_columns', None)  # all columns get..> pd.set_option('display.max_columns', None)

# %%
df.head(2)
# Out:
#    color   director_name  num_critic_for_reviews  duration  \
# 0  Color   James Cameron                   723.0     178.0
# 1  Color  Gore Verbinski                   302.0     169.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy
#
#   actor_1_name                                movie_title  num_voted_users  \
# 0  CCH Pounder                                    Avatar            886204
# 1  Johnny Depp  Pirates of the Caribbean: At World's End            471220
#
#    cast_total_facebook_likes    actor_3_name  facenumber_in_poster  \
# ...

# %%
pd.set_option('display.max_rows', df.shape[0]+1)  # all Rows get..> pd.set_option('display.max_columns', None)

# %%
df.head(6)       # show all rows , we put hear only (6) >>>Rows
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
# 5  Color     Andrew Stanton                   462.0     132.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
# 5                    475.0                   530.0   Samantha Morton
#
# ...

# %%
df.columns.values
# Out:
# array(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes',
#        'actor_2_name', 'actor_1_facebook_likes', 'gross', 'genres',
#        'actor_1_name', 'movie_title', 'num_voted_users',
#        'cast_total_facebook_likes', 'actor_3_name',
#        'facenumber_in_poster', 'plot_keywords', 'movie_imdb_link',
#        'num_user_for_reviews', 'language', 'country', 'content_rating',
#        'budget', 'title_year', 'actor_2_facebook_likes', 'imdb_score',
#        'aspect_ratio', 'movie_facebook_likes'], dtype=object)

# %%
df.shape
# Out:
# (5043, 28)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      5024 non-null   object
#  1   director_name              4939 non-null   object
#  2   num_critic_for_reviews     4993 non-null   float64
#  3   duration                   5028 non-null   float64
#  4   director_facebook_likes    4939 non-null   float64
#  5   actor_3_facebook_likes     5020 non-null   float64
#  6   actor_2_name               5030 non-null   object
#  7   actor_1_facebook_likes     5036 non-null   float64
#  8   gross                      4159 non-null   float64
#  9   genres                     5043 non-null   object
#  10  actor_1_name               5036 non-null   object
#  11  movie_title                5043 non-null   object
#  12  num_voted_users            5043 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# color                         19
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      12
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 2698

# %%
df.shape
# Out:
# (5043, 28)

# %%
5043 * 28   # Total..
# Out:
# 141204

# %%
df.isnull().sum().sum()   # isnull
# Out:
# 2698

# %%
df.notnull().sum().sum()   # is notnull  141204 - 2698 = 138506
# Out:
# 138506

# %% [markdown]
# # dropna

# %%
df1 = df.dropna(how = 'any')

# %%
df.head(6)
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
# 5  Color     Andrew Stanton                   462.0     132.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
# 5                    475.0                   530.0   Samantha Morton
#
# ...

# %%
df1.head(6)
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 5  Color     Andrew Stanton                   462.0     132.0
# 6  Color          Sam Raimi                   392.0     156.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 5                    475.0                   530.0   Samantha Morton
# 6                      0.0                  4000.0      James Franco
#
# ...

# %%
print(df.shape)
print(df1.shape)
# Out:
# (5043, 28)
# (3756, 28)

# %% [markdown]
# # fillna

# %%
df2 = df.fillna(value = 0)

# %%
df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
df2.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4      0        Doug Walker                     0.0       0.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     0.0        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
df.fillna(method='ffill').head()   # not work 'nan' to '0'
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4  Color        Doug Walker                   813.0     164.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                 23000.0        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
df4 = df.replace(0 ,np.nan)       # replace is worke..
df4.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      NaN                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      NaN                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
df4.loc[:,['gross','budget']].head()
# Out:
#          gross       budget
# 0  760505847.0  237000000.0
# 1  309404152.0  300000000.0
# 2  200074175.0  245000000.0
# 3  448130642.0  250000000.0
# 4          NaN          NaN

# %%
df[['gross','budget']].head()
# Out:
#          gross       budget
# 0  760505847.0  237000000.0
# 1  309404152.0  300000000.0
# 2  200074175.0  245000000.0
# 3  448130642.0  250000000.0
# 4          NaN          NaN

# %%
df4.loc[:,['gross','budget']] = df4.loc[:,['gross','budget']].fillna(value = 0)

# %%
df4.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      NaN                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      NaN                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
df4.loc[:,['gross','budget']].head()   # only 'gross' and 'budget' columns
# Out:
#          gross       budget
# 0  760505847.0  237000000.0
# 1  309404152.0  300000000.0
# 2  200074175.0  245000000.0
# 3  448130642.0  250000000.0
# 4          0.0          0.0

# %%
df4.loc[:,'language'].head()
# Out:
# 0    English
# 1    English
# 2    English
# 3    English
# 4        NaN
# Name: language, dtype: object

# %%
df4['language'].fillna('no info', inplace = True)

# %%
df4.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      NaN                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      NaN                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
df4.loc[:,'language'].head()    #  only 'Language' columns
# Out:
# 0    English
# 1    English
# 2    English
# 3    English
# 4    no info
# Name: language, dtype: object

# %%
df4.loc[:,'budget'].isnull().sum()
# Out:
# 0

# %%
df4.loc[:,'budget'].isnull().sum()
# Out:
# 0

# %%
df4.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      NaN                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      NaN                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
df5 = df.replace(0 ,np.nan)       # replace is worke..
df5.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      NaN                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      NaN                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
df5.loc[:,'budget'].head()
# Out:
# 0    237000000.0
# 1    300000000.0
# 2    245000000.0
# 3    250000000.0
# 4            NaN
# Name: budget, dtype: float64

# %%
df5['budget'].fillna(df4['budget'].mean(), inplace = True)

# %%
df5.loc[:,'budget'].head()      # 4 is min...
# Out:
# 0    2.370000e+08
# 1    3.000000e+08
# 2    2.450000e+08
# 3    2.500000e+08
# 4    3.587432e+07
# Name: budget, dtype: float64

# %%
df_duplicate_rows = df5[df5.duplicated()]
df_duplicate_rows.head()
# Out:
#      color director_name  num_critic_for_reviews  duration  \
# 137  Color   David Yates                   248.0     110.0
# 187  Color   Bill Condon                   322.0     115.0
# 204  Color  Hideaki Anno                     1.0     120.0
# 303  Color    Joe Wright                   256.0     111.0
# 389  Color    Josh Trank                   369.0     100.0
#
#      director_facebook_likes  actor_3_facebook_likes         actor_2_name  \
# 137                    282.0                   103.0  Alexander Skarsgård
# 187                    386.0                 12000.0      Kristen Stewart
# 204                     28.0                    12.0    Shin'ya Tsukamoto
# 303                    456.0                   394.0      Cara Delevingne
# 389                    128.0                    78.0        Reg E. Cathey
#
#      actor_1_facebook_likes        gross  \
# 137                 11000.0  124051759.0
# 187                 21000.0  292298923.0
# ...

# %%
df_duplicate_rows.shape
# Out:
# (45, 28)

# %%
df_duplicate_link = df5[df5.duplicated(['movie_imdb_link'])]
df_duplicate_link.shape
# Out:
# (124, 28)

# %%
op_labels = ['poor', 'moderate', 'good']
category = [0.,4.,7.,10.]
df5['imdb_labels'] = pd.cut(df5['imdb_score'],labels = op_labels, bins = category)

# %%
df5.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      NaN                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      NaN                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
df5.shape
# Out:
# (5043, 29)

# %%
# df[['C', 'D', 'E']]  # or df.loc[:, ['C', 'D', 'E']]

df5.loc[:,['movie_title','imdb_score','imdb_labels']][100:200]
# Out:
#                                            movie_title  imdb_score imdb_labels
# 100                          The Fast and the Furious          6.7    moderate
# 101               The Curious Case of Benjamin Button          7.8        good
# 102                                X-Men: First Class          7.8        good
# 103             The Hunger Games: Mockingjay - Part 2          6.6    moderate
# 104                         The Sorcerer's Apprentice          6.1    moderate
# 105                                          Poseidon          5.6    moderate
# 106                   Alice Through the Looking Glass          6.4    moderate
# 107                                   Shrek the Third          6.1    moderate
# 108                                          Warcraft          7.3        good
# 109                                Terminator Genisys          6.6    moderate
# 110  The Chronicles of Narnia: The Voyage of the Da...         6.3    moderate
# ...

# %% [markdown]
#                                          # OR

# %%
df5[['movie_title','imdb_score','imdb_labels']][100:200]
# Out:
#                                            movie_title  imdb_score imdb_labels
# 100                          The Fast and the Furious          6.7    moderate
# 101               The Curious Case of Benjamin Button          7.8        good
# 102                                X-Men: First Class          7.8        good
# 103             The Hunger Games: Mockingjay - Part 2          6.6    moderate
# 104                         The Sorcerer's Apprentice          6.1    moderate
# 105                                          Poseidon          5.6    moderate
# 106                   Alice Through the Looking Glass          6.4    moderate
# 107                                   Shrek the Third          6.1    moderate
# 108                                          Warcraft          7.3        good
# 109                                Terminator Genisys          6.6    moderate
# 110  The Chronicles of Narnia: The Voyage of the Da...         6.3    moderate
# ...
